# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\kerro\OneDrive\Bureau\smart_agri2\data\irrigation_prediction_17cols.csv")
df.head()
# Out:
#   Soil_Type  Soil_pH  Soil_Moisture  Organic_Carbon  Electrical_Conductivity  \
# 0      Clay     6.14          36.48            0.42                     2.17
# 1      Silt     6.41          50.56            0.38                     0.23
# 2     Sandy     7.71          40.07            1.09                     2.18
# 3      Clay     5.96          12.75            1.56                     0.40
# 4      Clay     7.76          18.58            0.95                     2.52
#
#    Temperature_C  Humidity  Rainfall_mm  Sunlight_Hours  Wind_Speed_kmh  \
# 0          21.90     31.19      1167.70            4.01            1.97
# 1          36.50     26.01       831.28           10.72           16.82
# 2          41.83     76.41      1844.45            7.75           19.03
# 3          37.22     43.32       306.26            8.90           11.44
# 4          22.38     86.44      1875.63           10.39           11.26
#
# ...

# %% [markdown]
# ### Supprimer des colonnes

# %%
df = df.drop(columns=[
    "Organic_Carbon",
    "Electrical_Conductivity",
    "Sunlight_Hours",
    "Previous_Irrigation_mm",
    "Irrigation_Need"
])

# %%
df.columns.tolist()
# Out:
# ['Soil_Type',
#  'Soil_pH',
#  'Soil_Moisture',
#  'Temperature_C',
#  'Humidity',
#  'Rainfall_mm',
#  'Wind_Speed_kmh',
#  'Crop_Type',
#  'Crop_Growth_Stage',
#  'Season',
#  'Mulching_Used',
#  'Region']

# %%
df.to_csv("data/irrigation_prediction_12cols.csv", index=False)

# %% [markdown]
# ##  - Ajout de la cible Soil_Moisture_J1
#
# Dans ce notebook, nous ajoutons une nouvelle colonne appelée `Soil_Moisture_J1`.
#
# Cette colonne représente une estimation de l'humidité du sol au jour suivant.
